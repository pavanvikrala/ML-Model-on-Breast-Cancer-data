# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
os.chdir("C:/Users/pavan/Breast Cancer dataset")

# %%
df = pd.read_csv("breast-cancer.csv")

# %%
df.sample(10)
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean
# 175    872113         B        8.671         14.45           54.42      227.2  \
# 265  88995002         M       20.730         31.12          135.70     1419.0
# 544    922297         B       13.870         20.70           89.77      584.8
# 123    865432         B       14.500         10.89           94.28      640.7
# 325  89511502         B       12.670         17.30           81.25      489.9
# 501     91504         M       13.820         24.49           92.33      595.9
# 305    893061         B       11.600         24.49           74.23      417.2
# 4    84358402         M       20.290         14.34          135.10     1297.0
# 29     853201         M       17.570         15.05          115.00      955.1
# 533  91930402         M       20.470         20.67          134.70     1299.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean
# ...

# %%
# Converting categorical labelled column into Binary

df['diagnosis'] = df['diagnosis'].map({'M': 1, 'B': 0}) # 1 means cancer is Malignant and 0 means benign

# %%
# Check the dimensions of the dataframe
df.shape
# Out:
# (569, 32)

# %%
df.info() # We can say that there are no null or missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    int64
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.describe()
# Out:
#                  id   diagnosis  radius_mean  texture_mean  perimeter_mean
# count  5.690000e+02  569.000000   569.000000    569.000000      569.000000  \
# mean   3.037183e+07    0.372583    14.127292     19.289649       91.969033
# std    1.250206e+08    0.483918     3.524049      4.301036       24.298981
# min    8.670000e+03    0.000000     6.981000      9.710000       43.790000
# 25%    8.692180e+05    0.000000    11.700000     16.170000       75.170000
# 50%    9.060240e+05    0.000000    13.370000     18.840000       86.240000
# 75%    8.813129e+06    1.000000    15.780000     21.800000      104.100000
# max    9.113205e+08    1.000000    28.110000     39.280000      188.500000
#
#          area_mean  smoothness_mean  compactness_mean  concavity_mean
# count   569.000000       569.000000        569.000000      569.000000  \
# mean    654.889104         0.096360          0.104341        0.088799
# std     351.914129         0.014064          0.052813        0.079720
# ...

# %%
df['diagnosis'].value_counts() # Out of 569 persons, 357 are benigh and 212 as malignant
# Out:
# diagnosis
# 0    357
# 1    212
# Name: count, dtype: int64

# %%
df.groupby('diagnosis').mean()
# Out:
#                      id  radius_mean  texture_mean  perimeter_mean
# diagnosis
# 0          2.654382e+07    12.146524     17.914762       78.075406  \
# 1          3.681805e+07    17.462830     21.604906      115.365377
#
#             area_mean  smoothness_mean  compactness_mean  concavity_mean
# diagnosis
# 0          462.790196         0.092478          0.080085        0.046058  \
# 1          978.376415         0.102898          0.145188        0.160775
#
#            concave points_mean  symmetry_mean  ...  radius_worst
# diagnosis                                      ...
# 0                     0.025717       0.174186  ...     13.379801  \
# 1                     0.087990       0.192909  ...     21.134811
#
#            texture_worst  perimeter_worst   area_worst  smoothness_worst
# diagnosis
# 0              23.515070        87.005938   558.899440          0.124959  \
# 1              29.318208       141.370330  1422.286321          0.144845
#
# ...

# %%
# Seperating the features and target

X = df.drop(columns='diagnosis', axis=1)
y = df['diagnosis']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report ,confusion_matrix, auc, roc_auc_score, roc_curve

def classify(model):
    """
    Trains the given model on the dataset, 
    calculates accuracy, displays classification report, 
    confusion matrix and plots ROC curves.

    Parameters:
        model: A scikit-learn model object

    Returns:
        None
    """ 
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # Feature scaling
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
    
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    score = accuracy_score(y_test, y_pred)*100
    print("Here's your Accuracy(%):", round(score,2))
    print('\n')
    
    cls_report = classification_report(y_test, y_pred, output_dict=True)
    df = pd.DataFrame(cls_report).transpose()
    print("Classification Report:")
    print(df)
    
    sns.heatmap(confusion_matrix(y_test, y_pred), 
                annot=True, fmt='3.0f', cmap="rocket")
    plt.title("Confusion Matrix", y=1.05, size=15)
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()
    
    #Plotting ROC curve
    y_probs = model.predict_proba(X_test)
    y_probs_positive = y_probs[:,1]
    
    # Calculating fpr, tpr and thresholds
    fpr, tpr, thresholds = roc_curve(y_test, y_probs_positive)
    plt.plot(fpr, tpr, color='green', label='ROC')
    # Plot line with no predictive power(baseline)
    plt.plot([0,1], [0,1], color="yellow", linestyle="--", label="Guessing")

    # Customize the plot
    plt.xlabel("False Positive Rate (fpr)")
    plt.ylabel("True Positive Rate (tpr)")
    plt.title("Receiver Operating Characteristic (ROC) curve")
    plt.legend()
    plt.show()

# %% [markdown]
# #### *As we're having the outcome variable or dependent variable as 0 or 1, we use Classification algorithm of supervised learning*

# %% [markdown]
# ### *Logistic Regression*

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
classify(model)
# Out:
# Here's your Accuracy(%): 98.25
#
#
# Classification Report:
#               precision    recall  f1-score     support
# 0              0.986301  0.986301  0.986301   73.000000
# 1              0.975610  0.975610  0.975610   41.000000
# accuracy       0.982456  0.982456  0.982456    0.982456
# macro avg      0.980956  0.980956  0.980956  114.000000
# weighted avg   0.982456  0.982456  0.982456  114.000000

# %% [markdown]
# ### *KNeighborsClassifier*

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=5)
classify(model)
# Out:
# Here's your Accuracy(%): 93.86
#
#
# Classification Report:
#               precision    recall  f1-score     support
# 0              0.912500  1.000000  0.954248   73.000000
# 1              1.000000  0.829268  0.906667   41.000000
# accuracy       0.938596  0.938596  0.938596    0.938596
# macro avg      0.956250  0.914634  0.930458  114.000000
# weighted avg   0.943969  0.938596  0.937136  114.000000

# %% [markdown]
# ### *Naive_Bayes Algorithm*

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
classify(model)
# Out:
# Here's your Accuracy(%): 89.47
#
#
# Classification Report:
#               precision    recall  f1-score     support
# 0              0.926471  0.900000  0.913043   70.000000
# 1              0.847826  0.886364  0.866667   44.000000
# accuracy       0.894737  0.894737  0.894737    0.894737
# macro avg      0.887148  0.893182  0.889855  114.000000
# weighted avg   0.896117  0.894737  0.895144  114.000000

# %% [markdown]
# ### *Decision Tree*

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion='entropy', random_state=7)
classify(model)
# Out:
# Here's your Accuracy(%): 90.35
#
#
# Classification Report:
#               precision    recall  f1-score     support
# 0              0.943662  0.905405  0.924138   74.000000
# 1              0.837209  0.900000  0.867470   40.000000
# accuracy       0.903509  0.903509  0.903509    0.903509
# macro avg      0.890436  0.902703  0.895804  114.000000
# weighted avg   0.906310  0.903509  0.904254  114.000000

# %% [markdown]
# ### *Random Forest*

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=10, criterion='entropy', random_state=7)
classify(model)
# Out:
# Here's your Accuracy(%): 93.86
#
#
# Classification Report:
#               precision    recall  f1-score     support
# 0              0.902778  1.000000  0.948905   65.000000
# 1              1.000000  0.857143  0.923077   49.000000
# accuracy       0.938596  0.938596  0.938596    0.938596
# macro avg      0.951389  0.928571  0.935991  114.000000
# weighted avg   0.944566  0.938596  0.937804  114.000000
